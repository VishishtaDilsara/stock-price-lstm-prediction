# %%
import numpy as np

data=np.load('data.npy')
target=np.load('target.npy')

# %%
train_data=data[:1000]
train_target=target[:1000]

test_data=data[1000:]
test_target=target[1000:]

print(train_data.shape)
print(test_data.shape)
print(train_target.shape)
print(test_target.shape)
# Out:
# (1000, 50, 1)
# (209, 50, 1)
# (1000, 1)
# (209, 1)

# %%
from matplotlib import pyplot as plt

plt.plot(train_target,'r',label='target')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Open Value/$')
plt.show()

# %%
from matplotlib import pyplot as plt

test_x_range=np.arange(1000,1209,1)
#test_x_range is an array of values between 1000-1208

plt.plot(train_target,'r',label='train')
plt.plot(test_x_range,test_target,'b',label='test')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Open Value/$')
plt.show()

# %%
from keras.models import Sequential
from keras.layers import LSTM,Dense,Dropout

model=Sequential()

model.add(LSTM(units=96,return_sequences=True,input_shape=(50,1)))
model.add(Dropout(0.2))

model.add(LSTM(units=96,return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=96,return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=40,return_sequences=False))
model.add(Dropout(0.2))

model.add(Dense(1,activation='linear'))

model.compile(loss='mse',optimizer='adam')
# Out:
# c:\Users\erang\Anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
history=model.fit(train_data,train_target,epochs=50,validation_data=(test_data,test_target))
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 175ms/step - loss: 0.0197 - val_loss: 0.0096
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 176ms/step - loss: 0.0042 - val_loss: 0.0088
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 143ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 142ms/step - loss: 0.0030 - val_loss: 0.0074
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - loss: 0.0027 - val_loss: 0.0066
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 149ms/step - loss: 0.0032 - val_loss: 0.0026
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 213ms/step - loss: 0.0026 - val_loss: 0.0091
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 171ms/step - loss: 0.0029 - val_loss: 0.0132
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - loss: 0.0024 - val_loss: 0.0032
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 161ms/step - loss: 0.0025 - val_loss: 0.0058
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - loss: 0.0025 - val_loss: 0.0063
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - loss: 0.0020 - val_loss: 0.0044
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 139ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - loss: 0.0020 - val_loss: 0.0045
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 145ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 205ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 216ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 0.0021 - val_loss: 0.0057
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 142ms/step - loss: 0.0020 - val_loss: 0.0035
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 176ms/step - loss: 0.0020 - val_loss: 0.0081
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 148ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 0.0020 - val_loss: 0.0043
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 150ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 135ms/step - loss: 0.0022 - val_loss: 0.0084
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 148ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 131ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 142ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - loss: 0.0019 - val_loss: 0.0083
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 143ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - loss: 0.0017 - val_loss: 0.0032
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step - loss: 0.0017 - val_loss: 0.0059
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 140ms/step - loss: 0.0015 - val_loss: 0.0037
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - loss: 0.0015 - val_loss: 0.0026
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 197ms/step - loss: 0.0013 - val_loss: 9.0433e-04
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - loss: 0.0013 - val_loss: 0.0042
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 132ms/step - loss: 0.0016 - val_loss: 0.0027
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 142ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - loss: 0.0012 - val_loss: 0.0037
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.0013 - val_loss: 8.7710e-04
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 0.0012 - val_loss: 0.0022
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - loss: 0.0012 - val_loss: 7.9145e-04
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - loss: 0.0013 - val_loss: 0.0039
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - loss: 0.0011 - val_loss: 0.0035
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 132ms/step - loss: 0.0013 - val_loss: 0.0033
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - loss: 0.0012 - val_loss: 9.5893e-04
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 140ms/step - loss: 0.0013 - val_loss: 0.0019

# %%
plt.plot(history.history['loss'],'r',label='train loss')
plt.plot(history.history['val_loss'],'g',label='val loss')
plt.xlabel('# epoch')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
result=model.predict(test_data)

from sklearn.metrics import r2_score

r2=r2_score(test_target,result)
print('r2 score:',r2)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 600ms/step
# r2 score: 0.7416491775833052

# %%
test_x_range=np.arange(1000,1209,1)
#test_x_range is an array of values between 1000-1208

plt.plot(train_target,'r',label='train')
plt.plot(test_x_range,test_target,'b',label='test')
plt.plot(test_x_range,result,'g',label='predicted')

plt.xlabel('Date')
plt.ylabel('Open Value/$')
plt.legend()
plt.show()

# %%
plt.plot(test_target,'b',label='test')
plt.plot(result,'g',label='predicted')

plt.xlabel('Date')
plt.ylabel('Open Value/$')
plt.legend()
plt.show()

# %%
model.save('LSTM-Stock-Market.keras')
